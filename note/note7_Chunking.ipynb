# %% [markdown]
# hiện chunking của mình đang theo token
# You sent
# ông có thể thử CHUNKING bằng tay
# You sent
# (cho nó ngắt đúng các ý hơn)
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# kiểu j
# You sent
# đây nè
# You sent
# You sent
# kiểu chunk 800 nó bị như này
# You sent
# ông có thể thử như sau.
#
# 1. Chunking theo kiểu : chunk_size + overlap + NGẮT TẠI các câu chứ không ngắt khi đủ token
#
# 2. Có thể chunking tay, tức là thay vì code để chunk theo 800 token, thì ông chunk bằng tay thành các đoạn
#
# xong nhét từng đoạn vào database.
# You sent
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# cảm ơn ô
# You sent
# Chắc cứ chỉnh UI trước, xong qua cải thiện chất lượng
# Thang Nguyen Van - RAG
# nếu mà mình fine tune thì chất lg cải thiện nhiều ko nhỉ
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# tôi tự làm bộ data hỏi đáp r á, k biết nên fine tune k
# Fri 5:52 PM
# You sent
# Click to see post
# Facebook
# Fri 7:23 PM
# You replied to Thang Nguyen Van - RAG
# Nếu kịp thì fine tune reranking model ô ạ
# Fri 10:06 PM
# Thang Nguyen Van - RAG
# theo t đọc thì hoặc là rag hoặc là fine tune
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# chứ ít khi dùng cả 2 nhỉ
# You sent
# Fine tune luôn data luật đó cũng được
#
# hoặc là fine turn model rerank Tiếng Việt với dataset khác để cải thiện RAG cho task truy vấn bộ luật
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# giúp t fine tune đc k
# Thang Nguyen Van - RAG
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# data qa t tự làm
# Sat 9:14 PM
# You sent
# Bao giờ bro phải nộp đó.
# Thang Nguyen Van - RAG
# nhanh k nhỉ b
# Thang Nguyen Van - RAG
# tầm 10/12 là hạn nộp docs
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# còn demo thì t chưa bt
# You sent
# Thế hơi căng,
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# fine tune cx lâu hả
# You sent
# Cũng nhanh,
# You sent
# Cơ mà tui cũng đang bị dí nhiều deadline trên trường
# Thang Nguyen Van - RAG
# uhm vậy chắc khó r
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# thế h chỉ còn cách chunk lại với thay model 7b thôi nhỉ
# Sat 11:05 PM
# You sent
# Đúm rùi
# You sent
# Mà nên chunk bằng tay
# You replied to yourself
# ...
# You sent
# Cho nó ngắt theo từng đoạn chuẩn luôn (theo từng điều)
# Thang Nguyen Van - RAG
# chunk bằng tay là ntn nhỉ
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# phải sửa file txt hả
# 12:36 AM
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# VALID_SOURCES = ["nttu", "wiki"] tại sao lại là nttu nhỉ
# 1:20 AM
# You sent
# nttu laf Nguyeen Tat Thành ô ạ
# You sent
# You sent
# backend sẽ có if - else như này
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# bro ngủ muộn mà vẫn dậy sớm đc à
# You replied to Thang Nguyen Van - RAG
# chunk tay là như này
#
# - Hiện tại đang là: code chunk theo token 800, nên là nó chia thành các đoạn theo token 800 (và hiển nhiên nhiều đoạn sẽ bị ngắt giữa chừng của câu => làm mất ý).
#
# - thì mình có thể tự chunk theo các đoạn: ĐÚNG Ý, NGẮT NGHỈ ĐÚNG CHỖ.
# You sent
# nếu cần thì ông cứ ngắt ra thành các đoạn đi, xong tôi nhét lên QDant cho
# You sent
# You sent
# You sent
# kiểu chia theo các đoạn chuẩn như này nè
# You sent
# dataset của mình cũng ko nhiều
# You sent
# You sent
# hoặc là để mỗi điều là 1 chunk (thay vì là để chunk size = 800, overlap như hiện tại)
# Thang Nguyen Van - RAG
# thế có dài quá k
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# nhiều điều dài phết
# You sent
# còn hơn là nó bị mất ý
# You sent
# You sent
# chẳng hạn điều 8 ông có thể chia thành 2-3 chunks
# You sent
# nhưng mà phải giữ cái HEADER của nó
# You sent
# You sent
# kiểu như này
# You sent
# vì mỗi đoạn chunks sẽ được embedding thành số
# You sent
# Câu truy vấn cũng được embedding,
# You sent
# xong nó so sánh độ tương đồng để tìm ra.
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# uk thì tức là phải edit file .txt đúng k
# You sent
# đúm
# You sent
# ko dài lắm đâu có gần 90 điều
# You replied to yourself
# cho lên cái file excel như này, xong tôi chạy code đẩy lên database cho
# Thang Nguyen Van - RAG
# Thang Nguyen Van
# thôi chia theo đoạn như kia thôi
# You sent
# chắc sửa lại UI trước đi
# - Xong qua Chunking
# - Xong thử model tiếng việt 7B quantize xuống (vẫn ngon hơn 3B đấy)
# -----------------
# là xong đồ án :v
#
# =======
# <thử kiếm xem model tiếng việt fine tune trên tập luật xem có không> chắc có đó, mình đỡ phải làm
# Write to Thang Nguyen Van

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ``
# CHƯƠNG I: ......
# Điều 8. Các hành vi bị nghiêm cấm
# 1. Phá hoại đường, cầu, hầm, bến phà đường bộ, đèn tín hiệu, cọc tiêu, biển báo hiệu, gương cầu, dải phân cách, hệ thống thoát nước và các công trình, thiết bị khác thuộc kết cấu hạ tầng giao thông đường bộ.
# 2. Đào, khoan, xẻ đường trái phép; đặt, để chướng ngại vật trái phép trên đường; đặt, rải vật nhọn, đổ chất gây trơn trên đường; để trái phép vật liệu, phế thải, thải rác ra đường; mở đường, đấu nối trái phép vào đường chính; lấn, chiếm hoặc sử dụng trái phép đất của đường bộ, hành lang an toàn đường bộ; tự ý tháo mở nắp cống, tháo dỡ, di chuyển trái phép hoặc làm sai lệch công trình đường bộ.
# 3. Sử dụng lòng đường, lề đường, hè phố trái phép.
# 4. Đưa xe cơ giới, xe máy chuyên dùng không bảo đảm tiêu chuẩn an toàn kỹ thuật và bảo vệ môi trường tham gia giao thông đường bộ.
# 5. Thay đổi tổng thành, linh kiện, phụ kiện xe cơ giới để tạm thời đạt tiêu chuẩn kỹ thuật của xe khi đi kiểm định.
# 6. Đua xe, cổ vũ đua xe, tổ chức đua xe trái phép, lạng lách, đánh võng.
# 7. Điều khiển phương tiện giao thông đường bộ mà trong cơ thể có chất ma túy.
#
#
#
# CHƯƠNG I: ......
# Điều 8. Các hành vi bị nghiêm cấm
# 8. Điều khiển xe ô tô, máy kéo, xe máy chuyên dùng trên đường mà trong máu hoặc hơi thở có nồng độ cồn.
# Điều khiển xe mô tô, xe gắn máy mà trong máu có nồng độ cồn vượt quá 50 miligam/100 mililít máu hoặc 0,25 miligam/1 lít khí thở.
# 9. Điều khiển xe cơ giới không có giấy phép lái xe theo quy định.
# Điều khiển xe máy chuyên dùng tham gia giao thông đường bộ không có chứng chỉ bồi dưỡng kiến thức pháp luật về giao thông đường bộ, bằng hoặc chứng chỉ điều khiển xe máy chuyên dùng.
# 10. Giao xe cơ giới, xe máy chuyên dùng cho người không đủ điều kiện để điều khiển xe tham gia giao thông đường bộ.
# 11. Điều khiển xe cơ giới chạy quá tốc độ quy định, giành đường, vượt ẩu.
# 12. Bấm còi, rú ga liên tục; bấm còi trong thời gian từ 22 giờ đến 5 giờ, bấm còi hơi, sử dụng đèn chiếu xa trong đô thị và khu đông dân cư, trừ các xe được quyền ưu tiên đang đi làm nhiệm vụ theo quy định của Luật này.
# 13. Lắp đặt, sử dụng còi, đèn không đúng thiết kế của nhà sản xuất đối với từng loại xe cơ giới; sử dụng thiết bị âm thanh gây mất trật tự an toàn giao thông, trật tự công cộng.
# 14. Vận chuyển hàng cấm lưu thông, vận chuyển trái phép hoặc không thực hiện đầy đủ các quy định về vận chuyển hàng nguy hiểm, động vật hoang dã.
# 15. Đe dọa, xúc phạm, tranh giành, lôi kéo hành khách; bắt ép hành khách sử dụng dịch vụ ngoài ý muốn; chuyển tải, xuống khách hoặc các hành vi khác nhằm trốn tránh phát hiện xe chở quá tải, quá số người quy định.
#
#
#
# CHƯƠNG I: ......
# Điều 8. Các hành vi bị nghiêm cấm
# 16. Kinh doanh vận tải bằng xe ô tô khi không đáp ứng đủ điều kiện kinh doanh theo quy định.
# 17. Bỏ trốn sau khi gây tai nạn để trốn tránh trách nhiệm.
# 18. Khi có điều kiện mà cố ý không cứu giúp người bị tai nạn giao thông.
# 19. Xâm phạm tính mạng, sức khỏe, tài sản của người bị nạn và người gây tai nạn.
# 20. Lợi dụng việc xảy ra tai nạn giao thông để hành hung, đe dọa, xúi giục, gây sức ép, làm mất trật tự, cản trở việc xử lý tai nạn giao thông.
# 21. Lợi dụng chức vụ, quyền hạn, nghề nghiệp của bản thân hoặc người khác để vi phạm pháp luật về giao thông đường bộ.
# 22. Sản xuất, sử dụng trái phép hoặc mua, bán biển số xe cơ giới, xe máy chuyên dùng.
# 23. Hành vi vi phạm quy tắc giao thông đường bộ, hành vi khác gây nguy hiểm cho người và phương tiện tham gia giao thông đường bộ.
# ```
